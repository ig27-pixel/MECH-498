# %%
from investment_base import InvestmentBase
from investment_fund import InvestmentFund, AFund, BFund, CFund #HINT -- you will need to add something here

# %%
print(InvestmentFund)
print(AFund)
print(AFund())
print(AFund().get_rate_by_year(2026))
# Out:
# <class 'investment_fund.InvestmentFund'>
# <class 'investment_fund.AFund'>
# <investment_fund.AFund object at 0x00000283C735CAD0>
# 0.08810000000000001
